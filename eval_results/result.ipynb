# %%
import pandas as pd
import os

# %%
# base and from pretrained
for dir in ["hate", "sentiment", "news"]:
    for distil_model in ["distil-emb-base", "distil-emb-small-gelu"]:
        for pretrained in ["pretrained", "scratch"]:
            xtemplate = f"{dir}_leobitz_{distil_model}_hs512_layers1_{pretrained}"
            template = "{template}_{idx}.csv"
            file_names = [template.format(template=xtemplate, idx=i) for i in range(1, 6)]
            files = os.listdir(dir)
            results = []
            for file_name in file_names:
                csv_path = os.path.join(dir, file_name)
                df = pd.read_csv(csv_path)
                out = df['f1_weighted'][13]
                results.append(out)
            print(f"{dir} | {distil_model} | {pretrained} | Mean F1-weighted: {sum(results)/len(results):.4f}")
    print()
# Out:
# hate | distil-emb-base | pretrained | Mean F1-weighted: 0.7861
# hate | distil-emb-base | scratch | Mean F1-weighted: 0.7829
# hate | distil-emb-small-gelu | pretrained | Mean F1-weighted: 0.7777
# hate | distil-emb-small-gelu | scratch | Mean F1-weighted: 0.7835
#
# sentiment | distil-emb-base | pretrained | Mean F1-weighted: 0.6335
# sentiment | distil-emb-base | scratch | Mean F1-weighted: 0.6158
# sentiment | distil-emb-small-gelu | pretrained | Mean F1-weighted: 0.6325
# sentiment | distil-emb-small-gelu | scratch | Mean F1-weighted: 0.6230
#
# news | distil-emb-base | pretrained | Mean F1-weighted: 0.8549
# news | distil-emb-base | scratch | Mean F1-weighted: 0.8167
# news | distil-emb-small-gelu | pretrained | Mean F1-weighted: 0.8424
# news | distil-emb-small-gelu | scratch | Mean F1-weighted: 0.8154
